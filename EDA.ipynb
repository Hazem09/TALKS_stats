# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
responses = pd.read_csv("Form responses.csv")
check_ins = pd.read_csv("CHECK_IN_cleaned.csv")

# %%
responses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 12 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                111 non-null    object
#  1   E-mail address                                                                                                           111 non-null    object
#  2   Full name                                                                                                                111 non-null    object
# ...

# %%
responses.head()
# Out:
#              Timestamp               E-mail address               Full name  \
# 0  11/02/2023 19:29:13       manismachou@gmail.com      machou mohamed anis
# 1  11/02/2023 19:29:30     medamine201515@gmail.com  DJANATI Mohamed Amine
# 2  11/02/2023 19:29:48      sarrabouali98@gmail.com           Bouali Sarra
# 3  11/02/2023 19:32:24  bensmainelyna023@gmail.com           Lyna bensmaine
# 4  11/02/2023 19:33:02     ishak.bouhalla@gmail.com         Ishak Bouhalla
#
#     Phone number°  Matricule° University : Current year :  \
# 0      0554869198         NaN        USTHB             L1
# 1      0558833834         NaN        USTHB             M2
# 2      0541129334         NaN        USTHB             M2
# 3      0675950223         NaN        USTHB             L2
# 4  +213 555734849         NaN        USTHB             M2
#
#   Mention your Major followed by your Specialty  \
# 0                            SNV / common trunk
# 1                                     M2 RO2MIR
# ...

# %%
responses.shape
# Out:
# (111, 12)

# %%
responses.columns =['timestamp','email','full_name','phone','matricule','university','year','major','club_member','previous_events','conference','contact_again']

# %%
for i in range(len(responses)):
    responses['full_name'][i]=responses['full_name'][i].lower()
# Out:
# C:\Users\g4mer\AppData\Local\Temp\ipykernel_11592\4040001056.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   responses['full_name'][i]=responses['full_name'][i].lower()

# %%
responses.head()
# Out:
#              timestamp                        email               full_name  \
# 0  11/02/2023 19:29:13       manismachou@gmail.com      machou mohamed anis
# 1  11/02/2023 19:29:30     medamine201515@gmail.com  djanati mohamed amine
# 2  11/02/2023 19:29:48      sarrabouali98@gmail.com           bouali sarra
# 3  11/02/2023 19:32:24  bensmainelyna023@gmail.com           lyna bensmaine
# 4  11/02/2023 19:33:02     ishak.bouhalla@gmail.com         ishak bouhalla
#
#             phone  matricule university year               major club_member  \
# 0      0554869198        NaN      USTHB   L1  SNV / common trunk        None
# 1      0558833834        NaN      USTHB   M2           M2 RO2MIR        None
# 2      0541129334        NaN      USTHB   M2                 ACC        None
# 3      0675950223        NaN      USTHB   L2                  Ro    ORS Club
# 4  +213 555734849        NaN      USTHB   M2        Master 2 AIP        None
#
# ...

# %%
year_count = responses['year'].value_counts()
year_count
# Out:
# L3                       44
# L2                       29
# M2                       16
# M1                       12
# L1                        6
# Titulaire master          1
# Data ingénieur            1
# employee                  1
# Fraîchement diplômée      1
# Name: year, dtype: int64

# %%
year_count_LMD = year_count[0:5]
year_count_LMD
# Out:
# L3    44
# L2    29
# M2    16
# M1    12
# L1     6
# Name: year, dtype: int64

# %%
plt.pie(year_count_LMD,labels=year_count_LMD.index,autopct='%1.1f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x19012ef4220>,
# ...
#  [Text(-1.0574867171849267, 0.30285614238025094, 'L3'),
#   Text(0.3183471742278275, -1.0529269094581815, 'L2'),
#   Text(1.0989333872562999, 0.04842943705429368, 'M2'),
#   Text(0.7125492648176702, 0.8380176282201931, 'M1'),
#   Text(0.1927798153660683, 1.0829755042416356, 'L1')],
#  [Text(-0.5768109366463237, 0.16519425948013686, '41.1%'),
#   Text(0.1736439132151786, -0.5743237687953716, '27.1%'),
#   Text(0.5994182112307089, 0.026416056575069277, '15.0%'),
#   Text(0.3886632353550928, 0.4571005244837416, '11.2%'),
#   Text(0.10515262656330997, 0.5907139114045284, '5.6%')])

# %%
university_count = responses['university'].value_counts()
university_count
# Out:
# USTHB                                                          103
# Esi                                                              1
# Ummto                                                            1
# Université d'alger 3                                             1
# Itfc                                                             1
# Sciences de l'information et communication ( Alger 03) itfc      1
# Dely brahim                                                      1
# Fac Centrale                                                     1
# École supérieure de journalisme                                  1
# Name: university, dtype: int64

# %%
club_count = responses['club_member'].value_counts()
club_count
# Out:
# None                   56
# ORS Club               36
# Micro club              3
# Omc                     2
# Micro club              2
# Micro Club              2
# MC                      2
# Gdsc                    1
# GDG Algiers             1
# MC                      1
# Readers club usthb      1
# Omc.                    1
# micro club              1
# Mc club                 1
# I was :(                1
# Name: club_member, dtype: int64

# %%
previous_events_count = responses['previous_events'].value_counts()
previous_events_count
# Out:
# NO     87
# YES    24
# Name: previous_events, dtype: int64

# %%
conference_count = responses['conference'].value_counts()
conference_count['First conference, Second conference']=conference_count['First conference, Second conference']+conference_count['First conference, second conference']
del conference_count['First conference, second conference']
print(conference_count)
# Out:
# First conference, Second conference    57
# First conference                       41
# Second conference                      13
# Name: conference, dtype: int64

# %%
plt.pie(conference_count,labels=conference_count.index,autopct='%1.1f%%')
plt.show()

# %%
check_ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   160 non-null    int64
#  1   name         160 non-null    object
#  2   last_name    155 non-null    object
#  3   middle_name  69 non-null     object
#  4   present      3 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 6.4+ KB

# %%
check_ins.head()
# Out:
#    Unnamed: 0        name last_name middle_name present
# 0           1  Abdelfetah       NaN         NaN     NaN
# 1           2  Abdelkader   Berkani         NaN     NaN
# 2           3     Abdelli      ryma                 NaN
# 3           4        ABDI     Naila         NaN     NaN
# 4           5     ACHERIR     Houas                 NaN

# %%
check_ins.shape
# Out:
# (160, 5)

# %%
for i in range(len(check_ins)):
    if check_ins['middle_name'][i] in ['P','p',0]:
        check_ins['present'][i] = check_ins['middle_name'][i]
        check_ins['middle_name'][i] = np.nan
# Out:
# C:\Users\g4mer\AppData\Local\Temp\ipykernel_11592\214199563.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_ins['present'][i] = check_ins['middle_name'][i]
# C:\Users\g4mer\AppData\Local\Temp\ipykernel_11592\214199563.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_ins['middle_name'][i] = np.nan

# %%
check_ins.fillna(' ', inplace=True)

# %%
check_ins['full_name'] = check_ins['name']+' '+ check_ins['last_name']+' '+check_ins['middle_name']

# %%
del check_ins['Unnamed: 0']
del check_ins['name']
del check_ins['last_name']
del check_ins['middle_name']

# %%
for i in range(len(check_ins)):
    check_ins['full_name'][i] = check_ins['full_name'][i].strip()

# %%
for i in range(len(responses)):
    responses['full_name'][i] = responses['full_name'][i].strip()
# Out:
# C:\Users\g4mer\AppData\Local\Temp\ipykernel_11592\2628141466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   responses['full_name'][i] = responses['full_name'][i].strip()

# %%
check_ins.head()
# Out:
#   present           full_name
# 0                  Abdelfetah
# 1          Abdelkader Berkani
# 2                Abdelli ryma
# 3                  ABDI Naila
# 4               ACHERIR Houas

# %%
check_ins = check_ins[['full_name','present']]

# %%
for i in range(len(check_ins)):
    check_ins['full_name'][i] = check_ins['full_name'][i].lower()
    check_ins['present'][i] = check_ins['present'][i].upper()

# %%
dfStyler = check_ins.style.set_properties(**{'text-align': 'left'})
dfStyler.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
# Out:
# <style type="text/css">
# #T_3b228 th {
#   text-align: left;
# }
# ...

# %%
check_ins.head()
# Out:
#             full_name present
# 0          abdelfetah
# 1  abdelkader berkani
# 2        abdelli ryma
# 3          abdi naila
# 4       acherir houas

# %%
check_ins['present'].value_counts()
total_present=check_ins['present'].value_counts()[1]

# %%
total_present
# Out:
# 61

# %%
df = pd.merge(responses,check_ins,on=['full_name'])
df.head()
# Out:
#              timestamp                        email              full_name  \
# 0  11/02/2023 19:29:30     medamine201515@gmail.com  djanati mohamed amine
# 1  11/02/2023 19:29:48      sarrabouali98@gmail.com           bouali sarra
# 2  11/02/2023 19:32:24  bensmainelyna023@gmail.com          lyna bensmaine
# 3  11/02/2023 19:33:02     ishak.bouhalla@gmail.com         ishak bouhalla
# 4  11/02/2023 19:33:41       houssemkenai@gmail.com   kenai houssem eddine
#
#             phone  matricule university year                major club_member  \
# 0      0558833834        NaN      USTHB   M2            M2 RO2MIR        None
# 1      0541129334        NaN      USTHB   M2                  ACC        None
# 2      0675950223        NaN      USTHB   L2                   Ro    ORS Club
# 3  +213 555734849        NaN      USTHB   M2         Master 2 AIP        None
# 4      0553742526        NaN      USTHB   L3  Operations research    ORS Club
#
# ...

# %%
df['present'].value_counts()
# Out:
#      91
# P    19
# Name: present, dtype: int64

# %%
19/total_present*100
# Out:
# 31.147540983606557

# %%
#TODO
#how many from the club were present ?
#
